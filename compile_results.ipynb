# %% [markdown]
# # Compile Results
#
# This notebook is purely to compile the results together after Verification. There are two main methods:
# - Grab all results for all questions
# - Filter results for specific questions

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.reporting import *
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### All question results

# %%
test_data = pd.read_csv('/data/metcloud-with-id.csv')

#determine which questions are METCLOUD specific for filtered results
metcloud_ids = []
for i,r in test_data.iterrows():
    if 'metcloud' in r['question'].lower():
        metcloud_ids.append(r['id'])

# %%
folder_to_dataframe('/data/Results/no_rag/',model_list=models).sort_values(by='average_accuracy')
# Out:
#                                                 model      time        tps  \
# 3       metcloud_1epoch_gemma-2-9b-it-bnb-4bit:latest  0.645270   0.000000
# 0                                              gemma2  7.174388  22.264301
# 9                                             mistral  6.168018  33.226657
# 2                                              llama3  7.445677  31.509900
# 10                                               phi3  7.622237  51.759784
# 7   metcloud_1epoch_Phi-3-mini-4k-instruct-bnb-4bi...  3.222316  43.390315
# 6   metcloud_1epoch_mistral-7b-instruct-v0.3-bnb-4...  4.140158  33.665221
# 1                                            llama3.1  6.479725  32.016442
# 8   metcloud_1epoch_Qwen2-7B-instruct-bnb-4bit:latest  3.609655  37.417866
# 11                                              qwen2  7.666361  33.297824
# 5   metcloud_1epoch_Meta-Llama-3.1-8B-Instruct-bnb...  4.828520  38.186514
# ...

# %% [markdown]
# ### Filtered question

# %%
models = [i.stem for i in Path('/data/Results/no_rag/gemma2').iterdir() if i.is_file()]
filter_folder_to_dataframe('/data/results/no_rag',model_list=models,ids=metcloud_ids)
# Out:
#     gemma2_accuracy  sem_accuracy  \
# 0          0.370370      0.962963
# 1          0.703704      0.814815
# 2          0.518519      0.962963
# 3          0.000000      0.000000
# 4          0.740741      0.962963
# 5          0.629630      0.925926
# 6          0.592593      0.962963
# 7          0.777778      0.925926
# 8          0.703704      0.925926
# 9          0.444444      0.777778
# 10         0.555556      0.925926
# 11         0.592593      0.888889
#
#                                                 model  llama3.1_accuracy  \
# 0                                              gemma2           0.666667
# 1                                            llama3.1           0.851852
# 2                                              llama3           0.740741
# 3       metcloud_1epoch_gemma-2-9b-it-bnb-4bit:latest           0.000000
# 4   metcloud_1epoch_llama-3-8b-Instruct-bnb-4bit:l...           0.851852
# ...
